# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
import pandas as pd 
df = pd.read_csv('./CSV/reviewMuscleBlaze(beginner).csv')

# %%
df = df.drop(columns = ['Unnamed: 0', 'name'])
df.fillna('0')
# Out:
#                                                  title  rating       date  \
# 0                                             Nice buy       4  23-Jan-19
# 1                          MB is nice but Bad shipping       5  16-Oct-18
# 2       Good protein for regular use and gym beginners       4   3-Jan-19
# 3                  Very Effective And Genuine Product.       5  22-May-18
# 4                                             Cheaters       1  28-Jan-19
# ..                                                 ...     ...        ...
# 610                                     Waste of money       1  20-Nov-19
# 611                                    Genuine product       5  25-Jan-19
# 612                         Very good quality protein.       5   7-Sep-20
# 613                                           Must buy       5  10-Sep-20
# 614  Found INSECT and PLASTIC material inside the p...       1   3-Sep-21
#
#                                                   text helpful_vote
# ...

# %%
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
from nltk.corpus import stopwords
nltk.download('stopwords')


import re
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hp\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
stop_words = set(stopwords.words('english'))

# %%
for sent in df['text']:
    print(sent)
    # print(word)
    print("\n")
# Out:
# Decent taste. Certainly original as I have verified it through their sms service. Only downside is mixing is really tough. I use a mixer and it still doesn't mix properly! Also doesn't mix well in hot milk. Never tried mixing using a shaker though. Also, I did a lot of calculations. This supplement offers one of the best protein/rupee ratio, much better than muscleblaze gold or massgainer pro and the likes. Of course, there is a limit to serving size so you can get only 12 g of protein at once. What I'm trying to say here is that it's cost-effective and bang for your buck
#
#
# Get this 💰 999Seems to be nice. As I heard about MB it is a genuine product that's why I buy this.Can give the review after use.But jar was broken when I get this.Amazing part is amazon refund it. Due to broken jar. Thanks
#
#
# ...

# %%
# word_count = []

# for sent in df['text']:
#     # Tokenization & Lemmatization of Words after removal of stop words 
#     words = nltk.tokenize.WhitespaceTokenizer().tokenize(sent)
#     filteredWords = [w for w in words if not w.lower() in stop_words]
#     lemmatizedWord = [nltk.stem.WordNetLemmatizer().lemmatize(word) for word in filteredWords]
    
#     finalList = []
    
#     for s in filteredWords:
#         s = re.sub("[^A-Za-z0-9]", "",s)
#         finalList.append(s)
    
#     filteredWords =finalList
#     length = len(set(filteredWords))
#     word_count.append(length)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# c:\Users\hp\Desktop\BTP\EDA.ipynb Cell 6 in <cell line: 3>()
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/BTP/EDA.ipynb#W5sZmlsZQ%3D%3D?line=0'>1</a> word_count = []
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/BTP/EDA.ipynb#W5sZmlsZQ%3D%3D?line=2'>3</a> for sent in df['text']:
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/BTP/EDA.ipynb#W5sZmlsZQ%3D%3D?line=3'>4</a>     # Tokenization & Lemmatization of Words after removal of stop words
# ----> <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/BTP/EDA.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a>     words = nltk.tokenize.WhitespaceTokenizer().tokenize(sent)
#       <a href='vscode-notebook-cell:/c%3A/Users/hp/Desktop/BTP/EDA.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>     filteredWords = [w for w in words if not w.lower() in stop_words]
# ...

# %%
print(type(nltk.stem.WordNetLemmatizer().lemmatize("hell")))
# Out:
# <class 'str'>
