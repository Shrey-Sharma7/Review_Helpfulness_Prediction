# %% [markdown]
# <h1>Exploratory Data Analysis</h1>

# %%
import pandas as pd
import numpy as np
import nltk 
import pickle 
import pyLDAvis
import pyLDAvis.sklearn
from collections import Counter
from textblob import TextBlob
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import LatentDirichletAllocation, NMF
from wordcloud import WordCloud, ImageColorGenerator
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('wheyprotein_clean.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  rating                                               text  \
# 0         228       1  After using 20 days came to know that this wor...
# 1         502       3       Tastes like cum . chocolate cum cookies. Cum
# 2         542       1  Seal broken mili hai upar se kisi kaam ka prot...
# 3         659       3                                                 Ok
# 4         698       1                                          Bad taste
#
#   helpful_vote                                        no_contract  \
# 0            0  ['After', 'using', '20', 'days', 'came', 'to',...
# 1            0  ['Tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2            0  ['Seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3            0                                             ['Ok']
# 4            0                                   ['Bad', 'taste']
#
#                                           review_str langs  \
# 0  After using 20 days came to know that this wor...    hi
# 1       Tastes like cum . chocolate cum cookies. Cum    la
# 2  Seal broken mili hai upar se kisi kaam ka prot...    fi
# 3                                                 Ok    it
# 4                                          Bad taste    it
#
#                                            tokenized  \
# 0  ['After', 'using', '20', 'days', 'came', 'to',...
# 1  ['Tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2  ['Seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['Ok']
# 4                                   ['Bad', 'taste']
#
#                                                lower  \
# 0  ['after', 'using', '20', 'days', 'came', 'to',...
# 1  ['tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                              no_punc  \
# 0  ['after', 'using', '20', 'days', 'came', 'to',...
# 1  ['tastes', 'like', 'cum', 'chocolate', 'cum', ...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                    stopwords_removed  \
# 0  ['using', '20', 'days', 'came', 'know', 'worst...
# 1  ['tastes', 'like', 'cum', 'chocolate', 'cum', ...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                             pos_tags  \
# 0  [('using', 'VBG'), ('20', 'CD'), ('days', 'NNS...
# 1  [('tastes', 'NNS'), ('like', 'IN'), ('cum', 'N...
# 2  [('seal', 'NN'), ('broken', 'JJ'), ('mili', 'N...
# 3                                     [('ok', 'NN')]
# 4                   [('bad', 'JJ'), ('taste', 'NN')]
#
#                                          wordnet_pos  \
# 0  [('using', 'v'), ('20', 'n'), ('days', 'n'), (...
# 1  [('tastes', 'n'), ('like', 'n'), ('cum', 'n'),...
# 2  [('seal', 'n'), ('broken', 'a'), ('mili', 'n')...
# 3                                      [('ok', 'n')]
# 4                     [('bad', 'a'), ('taste', 'n')]
#
#                                           lemmatized
# 0  ['use', '20', 'day', 'come', 'know', 'bad', 'p...
# 1  ['taste', 'like', 'cum', 'chocolate', 'cum', '...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']

# %%
df = df.drop(['Unnamed: 0'], axis = 1)

# %%
df.head()
# Out:
#    rating                                               text helpful_vote  \
# 0       1  After using 20 days came to know that this wor...            0
# 1       3       Tastes like cum . chocolate cum cookies. Cum            0
# 2       1  Seal broken mili hai upar se kisi kaam ka prot...            0
# 3       3                                                 Ok            0
# 4       1                                          Bad taste            0
#
#                                          no_contract  \
# 0  ['After', 'using', '20', 'days', 'came', 'to',...
# 1  ['Tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2  ['Seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['Ok']
# 4                                   ['Bad', 'taste']
#
#                                           review_str langs  \
# 0  After using 20 days came to know that this wor...    hi
# 1       Tastes like cum . chocolate cum cookies. Cum    la
# 2  Seal broken mili hai upar se kisi kaam ka prot...    fi
# 3                                                 Ok    it
# 4                                          Bad taste    it
#
#                                            tokenized  \
# 0  ['After', 'using', '20', 'days', 'came', 'to',...
# 1  ['Tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2  ['Seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['Ok']
# 4                                   ['Bad', 'taste']
#
#                                                lower  \
# 0  ['after', 'using', '20', 'days', 'came', 'to',...
# 1  ['tastes', 'like', 'cum', '.', 'chocolate', 'c...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                              no_punc  \
# 0  ['after', 'using', '20', 'days', 'came', 'to',...
# 1  ['tastes', 'like', 'cum', 'chocolate', 'cum', ...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                    stopwords_removed  \
# 0  ['using', '20', 'days', 'came', 'know', 'worst...
# 1  ['tastes', 'like', 'cum', 'chocolate', 'cum', ...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']
#
#                                             pos_tags  \
# 0  [('using', 'VBG'), ('20', 'CD'), ('days', 'NNS...
# 1  [('tastes', 'NNS'), ('like', 'IN'), ('cum', 'N...
# 2  [('seal', 'NN'), ('broken', 'JJ'), ('mili', 'N...
# 3                                     [('ok', 'NN')]
# 4                   [('bad', 'JJ'), ('taste', 'NN')]
#
#                                          wordnet_pos  \
# 0  [('using', 'v'), ('20', 'n'), ('days', 'n'), (...
# 1  [('tastes', 'n'), ('like', 'n'), ('cum', 'n'),...
# 2  [('seal', 'n'), ('broken', 'a'), ('mili', 'n')...
# 3                                      [('ok', 'n')]
# 4                     [('bad', 'a'), ('taste', 'n')]
#
#                                           lemmatized
# 0  ['use', '20', 'day', 'come', 'know', 'bad', 'p...
# 1  ['taste', 'like', 'cum', 'chocolate', 'cum', '...
# 2  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...
# 3                                             ['ok']
# 4                                   ['bad', 'taste']

# %%
df = df[['rating','lemmatized', 'helpful_vote']]
df.head()
# Out:
#    rating                                         lemmatized helpful_vote
# 0       1  ['use', '20', 'day', 'come', 'know', 'bad', 'p...            0
# 1       3  ['taste', 'like', 'cum', 'chocolate', 'cum', '...            0
# 2       1  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...            0
# 3       3                                             ['ok']            0
# 4       1                                   ['bad', 'taste']            0

# %%
df['lemma_str'] = [' '.join(map(str,l)) for l in df['lemmatized']]
df.head()
# Out:
#    rating                                         lemmatized helpful_vote  \
# 0       1  ['use', '20', 'day', 'come', 'know', 'bad', 'p...            0
# 1       3  ['taste', 'like', 'cum', 'chocolate', 'cum', '...            0
# 2       1  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...            0
# 3       3                                             ['ok']            0
# 4       1                                   ['bad', 'taste']            0
#
#                                            lemma_str
# 0  [ ' u s e ' ,   ' 2 0 ' ,   ' d a y ' ,   ' c ...
# 1  [ ' t a s t e ' ,   ' l i k e ' ,   ' c u m ' ...
# 2  [ ' s e a l ' ,   ' b r o k e n ' ,   ' m i l ...
# 3                                        [ ' o k ' ]
# 4                    [ ' b a d ' ,   ' t a s t e ' ]

# %%
df['sentiment'] = df['lemma_str'].apply(lambda x: TextBlob(x).sentiment.polarity)
df.head()
# Out:
#    rating                                         lemmatized helpful_vote  \
# 0       1  ['use', '20', 'day', 'come', 'know', 'bad', 'p...            0
# 1       3  ['taste', 'like', 'cum', 'chocolate', 'cum', '...            0
# 2       1  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...            0
# 3       3                                             ['ok']            0
# 4       1                                   ['bad', 'taste']            0
#
#                                            lemma_str  sentiment
# 0  [ ' u s e ' ,   ' 2 0 ' ,   ' d a y ' ,   ' c ...        0.0
# 1  [ ' t a s t e ' ,   ' l i k e ' ,   ' c u m ' ...        0.0
# 2  [ ' s e a l ' ,   ' b r o k e n ' ,   ' m i l ...        0.0
# 3                                        [ ' o k ' ]        0.0
# 4                    [ ' b a d ' ,   ' t a s t e ' ]        0.0

# %%
df.drop('sentiment', axis = 1)
# Out:
#      rating                                         lemmatized helpful_vote  \
# 0         1  ['use', '20', 'day', 'come', 'know', 'bad', 'p...            0
# 1         3  ['taste', 'like', 'cum', 'chocolate', 'cum', '...            0
# 2         1  ['seal', 'broken', 'mili', 'hai', 'upar', 'se'...            0
# 3         3                                             ['ok']            0
# 4         1                                   ['bad', 'taste']            0
# ..      ...                                                ...          ...
# 174       5                                   ['taste', '100']            2
# 175       5                               ['excellent', '...']            1
# 176       1                                      ['duplicate']            5
# 177       1                                           ['fake']            2
# 178       1                         ['�', 'dublicate', 'whey']            1
#
#                                              lemma_str
# 0    [ ' u s e ' ,   ' 2 0 ' ,   ' d a y ' ,   ' c ...
# 1    [ ' t a s t e ' ,   ' l i k e ' ,   ' c u m ' ...
# 2    [ ' s e a l ' ,   ' b r o k e n ' ,   ' m i l ...
# 3                                          [ ' o k ' ]
# 4                      [ ' b a d ' ,   ' t a s t e ' ]
# ..                                                 ...
# 174                    [ ' t a s t e ' ,   ' 1 0 0 ' ]
# 175            [ ' e x c e l l e n t ' ,   ' . . . ' ]
# 176                          [ ' d u p l i c a t e ' ]
# 177                                    [ ' f a k e ' ]
# 178  [ ' � ' ,   ' d u b l i c a t e ' ,   ' w h e ...
#
# [179 rows x 4 columns]
